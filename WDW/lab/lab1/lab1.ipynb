# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
m = 10_000

# %%
x = np.random.rand(m)

# %%
print(len(x))
print(min(x))
print(max(x))
# Out:
# 10000
# 0.00010320947988129436
# 0.9997878893297995

# %%
df = pd.DataFrame(x)

# %%
df.hist(bins=10)
# Out:
# array([[<Axes: title={'center': '0'}>]], dtype=object)

# %%
y = np.random.rand(m)
z = x + y

# %%
z[z < 1] = 1 + (1 - z[z < 1])

# %%
pd.DataFrame(z).hist(bins=10)
# Out:
# array([[<Axes: title={'center': '0'}>]], dtype=object)

# %%
pd.DataFrame(np.random.rand(m) + np.random.rand(m) + np.random.rand(m)).hist(bins=1000)
# Out:
# array([[<Axes: title={'center': '0'}>]], dtype=object)

# %%
plt.plot(x)

# %% [markdown]
# ##### Narysuj trojkat

# %%
def trojkat(m):
    x = np.linspace(0, 1, m)
    y = np.random.rand(m) + np.random.rand(m)
    return x,y

x,y = trojkat(1000)
plt.scatter(x, y)
